# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url ='https://mbstar.pixnet.net/blog/post/27989163-%e5%b9%b8%e9%81%8b%e4%b9%8b%e6%98%9f%e8%ab%8b%e4%be%86%e9%9b%bb%ef%bc%81%e8%b6%85lucky%e6%89%8b%e6%a9%9f%e9%9d%88%e6%95%b8?fbclid=IwAR2xcoBp6gs6b7UV1aRD4wdCb7A8C1E5PVMMuUxcLD0bvNc62J9UHN3guX0'

# %% [markdown]
# 爬找算命網站

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<html lang="zh-TW" itemscope itemtype="http://schema.org/Blog">\n<head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<meta name="referrer" content="unsafe-url">\n<meta property="og:site_name" content="è«\x87æ\x98\x9fç\x9a\x84å¹¸ç¦\x8fé\x83¨è\x90½">\n<meta property="og:locale" content="zh_TW">\n<meta property="og:url" content="http://mbstar.pixnet.net/blog/post/27989163">\n<meta property="og:type" content="article" />\n<meta property="og:title" content="å¹¸é\x81\x8bä¹\x8bæ\x98\x9fè«\x8bä¾\x86é\x9b»ï¼\x81è¶\x85Luckyæ\x89\x8bæ©\x9fé\x9d\x88æ\x95¸ @ è«\x87æ\x98\x9fç\x9a\x84å¹¸ç¦\x8fé\x83¨è\x90½ :: ç\x97\x9eå®¢é\x82¦ ::" />\n<meta property="og:description" content="ä»\x80éº¼æ¨£ç\x9a\x84æ\x89\x8bæ©\x9fè\x99\x9fç¢¼æ\x9c\x83å¸¶ä¾\x86æ\x80\x8eéº¼æ¨£ç\x9a\x84æ\x95\x88æ\x9e\x9c
# ...

# %% [markdown]
# 改編碼

# %%
resp.encoding = 'utf-8'

# %%
soup = BeautifulSoup(resp.text,'lxml')
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html itemscope="" itemtype="http://schema.org/Blog" lang="zh-TW">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="談星的幸福部落" property="og:site_name"/>
# <meta content="zh_TW" property="og:locale"/>
# <meta content="http://mbstar.pixnet.net/blog/post/27989163" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="幸運之星請來電！超Lucky手機靈數 @ 談星的幸福部落 :: 痞客邦 ::" property="og:title"/>
# <meta content="什麼樣的手機號碼會帶來怎麼樣的效果呢？ 西洋靈數學的理論是～ 你身邊有數字的東西都會對你產生影響力， 而現代人身邊最重要的隨身物品是什麼呢？ 應該有很多人會毫不猶豫地說：「當然是手機囉！」 因為它如" property="og:description"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
ps=soup.find(id="article-content-inner").find_all('p')
ps
# Out:
# [<p><img alt="cellphone.jpg" border="0" loading="lazy" src="https://pic.pimg.tw/mbstar/4aa9cc6a7c1c0.jpg" style="border: 0; float: left;" title="cellphone.jpg"/> </p>,
#  <p><span style="font-size: 12pt;"><span style="color: #800080;">什麼樣的手機號碼會帶來怎麼樣的效果呢？</span></span></p>,
#  <p>西洋靈數學的理論是～</p>,
#  <p>你身邊有數字的東西都會對你產生影響力，</p>,
#  <p>而現代人身邊最重要的隨身物品是什麼呢？</p>,
#  <p>應該有很多人會毫不猶豫地說：「當然是手機囉！」</p>,
#  <p>因為它如此重要，所以手機號碼會對我們產生極大的影響力！</p>,
#  <p>通常越是頻繁使用手機的人，就越會被手機的號碼所影響。</p>,
#  <p>◎文╱繆心　◎圖╱日光花</p>,
#  <p><!-- more --></p>,
#  <p><strong> </strong></p>,
#  <p><strong>手機靈數的算法：</strong></p>,
#  <p>1.請把手機號碼的每個數字加起來。</p>,
#  <p>比如說小明的手機號碼是0900846778，</p>,
#  <p>那就把　<span style="font-size: 12pt;"><strong><span style="color: #800080;">0+9+0+0+8+4+6+7+7+8=49</span></strong></span></p>,
#  <p>2.再將最後的十位數字加起來，<span style="font-size: 12pt;"><span style="color: #800080;"><strong>4+9=13</strong></span></span></p>,
# ...

# %%
len(ps)
# Out:
# 43

# %%
ps[21:39]
# Out:
# [<p><strong><span style="color: #800080;">手機靈數1　　閒雜人等勿近</span></strong></p>,
#  <p>這個數字會帶給你獨立自主的精神，但是也因此而有些孤僻的傾向，這支手機常常會沒接到電話，或是會過濾掉不少人的電話，所以大部份的時候都是你在打電話給別人，別人可能會因為一直打不通你的電話而放棄哩！</p>,
#  <p><strong><span style="color: #800080;">手機靈數2　　情人專用熱線</span></strong></p>,
#  <p>這個手機號碼會有強大的待機功能，可能會持續等待他人回電或是打電話給你，通常很少漏接正在等待的電話，2號數字會讓你接電話的次數比打電話多得多，尤其最重要的，一定不會漏接情人或是心儀對象的來電！</p>,
#  <p><strong><span style="color: #800080;">手機靈數3　　強力發電機</span></strong></p>,
#  <p>3號手機可以說是手機中的極品，因為他掌管的就是手機最重要的溝通交流功能，許多當面都很難溝通的對象，遇到這個號碼簡直是救星，立刻變得溝通無障礙！這個號碼很少有接不到電話的困擾，非常適合聊天使用。</p>,
#  <p><strong><span style="color: #800080;">手機靈數4　　超級事務機</span></strong></p>,
#  <p>4號手機最大的特點在於沒有用的來電是接不到的，能夠接到的電話必定都是無事不登三寶殿，越是重要的事就越不容易漏接，所以依此類推，那些找你吃喝玩樂的來電就很少打得進來了，因而最適合推薦給忙碌的人使用。</p>,
#  <p><strong><span style="color: #800080;">手機靈數5　　超強資訊站</span></strong></p>,
#  <p>靈數5的手機才真是最強收發的超強資訊站，不管到哪裡，不管要收什麼，5號機絕對不會讓你失望，就算只是小廣告、會員通知，這個號碼都照單全收，絕對不會漏接任何資訊。另外這個號碼也最適合全區漫遊的服務。</p>,
# ...

# %% [markdown]
# 成對解析

# %%
ps[37].text.split()+ps[38].text.split()
# Out:
# ['手機靈數9',
#  '奇人異事機',
#  '9號手機是一支什麼電話都會接到的機子，而且通常接到的閒雜電話比有用的電話多得多，也時有意外的斷線。這真是一支奇怪的號碼，不過這個號碼會為你帶來感應力，你常常有神準的預知力，甚至知道誰就要打電話來了！']

# %%
datas=[]
for i in range(21,39):
    if i %2 != 0:
        line = ps[i].text.split()+ps[i+1].text.split()
        print(line)
        datas.append(line)

print(datas)
# Out:
# ['手機靈數1', '閒雜人等勿近', '這個數字會帶給你獨立自主的精神，但是也因此而有些孤僻的傾向，這支手機常常會沒接到電話，或是會過濾掉不少人的電話，所以大部份的時候都是你在打電話給別人，別人可能會因為一直打不通你的電話而放棄哩！']
# ['手機靈數2', '情人專用熱線', '這個手機號碼會有強大的待機功能，可能會持續等待他人回電或是打電話給你，通常很少漏接正在等待的電話，2號數字會讓你接電話的次數比打電話多得多，尤其最重要的，一定不會漏接情人或是心儀對象的來電！']
# ['手機靈數3', '強力發電機', '3號手機可以說是手機中的極品，因為他掌管的就是手機最重要的溝通交流功能，許多當面都很難溝通的對象，遇到這個號碼簡直是救星，立刻變得溝通無障礙！這個號碼很少有接不到電話的困擾，非常適合聊天使用。']
# ['手機靈數4', '超級事務機', '4號手機最大的特點在於沒有用的來電是接不到的，能夠接到的電話必定都是無事不登三寶殿，越是重要的事就越不容易漏接，所以依此類推，那些找你吃喝玩樂的來電就很少打得進來了，因而最適合推薦給忙碌的人使用。']
# ['手機靈數5', '超強資訊站', '靈數5的手機才真是最強收發的超強資訊站，不管到哪裡，不管要收什麼，5號機絕對不會讓你失望，就算只是小廣告、會員通知，這個號碼都照單全收，絕對不會漏接任何資訊。另外這個號碼也最適合全區漫遊的服務。']
# ['手機靈數6', '無敵浪漫手機', '靈數6號的手機是非常浪漫的，也就是說最適合用手機談戀愛，如果想用電話讓感情加溫，那麼6號是最好的選擇。當然不是想拿這個機子來談戀愛的人，其實就比較不宜選這個號碼，因為這支手機是很容易營造曖昧氣氛的。']
# ['手機靈數7', '超性格派機種', '靈數7的手機肯定是最性格的手機了啦！平常的來電大多愛接不接的，會增加你特立獨行的氣質，而且通常7號手機八卦話題極少，溝通想法與事務的機會比較多，所以如果覺得自己不夠酷、不夠有個性，就選用7號吧！']
# ['手機靈數8', '大發利巿機', '手機靈數8的人人脈極廣，而且通常都是有用的人脈，讓你的手機消息靈通，但卻又沒有不中用的怪訊息。8號是一個順暢的數字，非常適合時常需要交流應酬的人，8號的手機將帶給你旺盛的氣盛，還有意外獲利的機會哦！']
# ...

# %%
pd.DataFrame(datas,columns=['靈數','機別','結果'])
